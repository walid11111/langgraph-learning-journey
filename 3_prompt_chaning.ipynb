# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
import os

if not os.getenv("GROQ_API_KEY"):    print("Warning: GROQ_API_KEY not set. Create a .env with GROQ_API_KEY or set the environment variable to call the API.")

# %%
model = ChatGroq(model="llama-3.1-8b-instant")

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': '**Title:** "The Rise of AI in India: Opportunities, Challenges, and Future Prospects"\n\n**I. Introduction**\n\n* Brief overview of AI and its significance in modern times\n* Importance of India as a hub for AI adoption and innovation\n* Thesis statement: India is poised to become a global leader in AI adoption, driven by government initiatives, technological advancements, and a growing demand for digital transformation.\n\n**II. Government Initiatives and Policies**\n\n* Overview of government initiatives such as:\n\t+ Digital India Programme\n\t+ Smart City Mission\n\t+ National Policy on Artificial Intelligence (2018)\n* Discussion on the role of government in promoting AI adoption and innovation in India\n* Analysis of the impact of government policies on the AI ecosystem in India\n\n**III. AI Adoption in Key Sectors**\n\n* Overview of AI adoption in various sectors, including:\n\t+ Healthcare: use of AI in medical diagnosis, patient care, and telemedicine\n\t+ Finance: use of AI in banking, insurance, and financial inclusion\n\t+ Education: use of AI in personalized learning, online education, and skill development\n\t+ Manufacturing: use of AI in quality control, predictive maintenance, and supply chain management\n* Discussion on the benefits and challenges of AI adoption in each sector\n\n**IV. AI Startups and Entrepreneurship**\n\n* Overview of the AI startup ecosystem in India, including:\n\t+ Number of AI startups, funding, and success stories\n\t+ Role of accelerators, incubators, and venture capital firms in promoting AI startups\n* Discussion on the challenges faced by AI startups in India, including funding, talent acquisition, and regulation\n\n**V. Talent Acquisition and Development**\n\n* Overview of the talent shortage in AI and data science in India\n* Discussion on the need for AI education and training programs in India\n* Analysis of government initiatives and private sector efforts to develop AI talent in India\n\n**VI. Challenges and Concerns**\n\n* Discussion on the potential challenges and concerns related to AI adoption in India, including:\n\t+ Job displacement and unemployment\n\t+ Bias and fairness in AI systems\n\t+ Cybersecurity and data protection\n\t+ Regulatory frameworks and governance\n\n**VII. Future Prospects and Opportunities**\n\n* Analysis of the future prospects and opportunities for AI in India, including:\n\t+ Emerging industries and applications of AI, such as autonomous vehicles and robotics\n\t+ Growing demand for AI talent and skills\n\t+ Potential for AI to drive economic growth and development in India\n\n**VIII. Conclusion**\n\n* Summary of the key points discussed in the blog post\n* Final thoughts on the rise of AI in India and its potential to transform the country\'s economy and society.\n\n**IX. References**\n\n* List of sources cited in the blog post, including academic papers, industry reports, and news articles.\n\nThis outline provides a comprehensive structure for a detailed blog post on the rise of AI in India, covering various aspects of AI adoption, government initiatives, startup ecosystem, talent acquisition, challenges, and future prospects.', 'content': '**The Rise of AI in India: Opportunities, Challenges, and Future Prospects**\n\n**I. Introduction**\n\nArtificial Intelligence (AI) has revolutionized various industries and aspects of modern life, transforming the way we live, work, and interact with each other. As the world becomes increasingly dependent on AI, India is poised to become a global leader in AI adoption and innovation. With its burgeoning population, growing economy, and favorable government policies, India is uniquely positioned to harness the power of AI and drive digital transformation.\n\nIndia\'s significance as a hub for AI adoption and innovation lies in its vast talent pool, entrepreneurial spirit, and government initiatives that promote innovation and digital growth. The Indian government  ...

# %%
print(final_state['outline'])
# Out:
# **Title:** "The Rise of AI in India: Opportunities, Challenges, and Future Prospects"
#
# **I. Introduction**
#
# * Brief overview of AI and its significance in modern times
# * Importance of India as a hub for AI adoption and innovation
# * Thesis statement: India is poised to become a global leader in AI adoption, driven by government initiatives, technological advancements, and a growing demand for digital transformation.
#
# **II. Government Initiatives and Policies**
#
# * Overview of government initiatives such as:
# 	+ Digital India Programme
# 	+ Smart City Mission
# 	+ National Policy on Artificial Intelligence (2018)
# * Discussion on the role of government in promoting AI adoption and innovation in India
# * Analysis of the impact of government policies on the AI ecosystem in India
#
# **III. AI Adoption in Key Sectors**
#
# * Overview of AI adoption in various sectors, including:
# 	+ Healthcare: use of AI in medical diagnosis, patient care, and telemedicine
# 	+ Finance: use of AI in banking, insurance, and financial inclusion
# 	+ Education: use of AI in personalized learning, online education, and skill development
# 	+ Manufacturing: use of AI in quality control, predictive maintenance, and supply chain management
# * Discussion on the benefits and challenges of AI adoption in each sector
#
# **IV. AI Startups and Entrepreneurship**
#
# * Overview of the AI startup ecosystem in India, including:
# 	+ Number of AI startups, funding, and success stories
# 	+ Role of accelerators, incubators, and venture capital firms in promoting AI startups
# * Discussion on the challenges faced by AI startups in India, including funding, talent acquisition, and regulation
#
# **V. Talent Acquisition and Development**
#
# * Overview of the talent shortage in AI and data science in India
# * Discussion on the need for AI education and training programs in India
# * Analysis of government initiatives and private sector efforts to develop AI talent in India
#
# **VI. Challenges and Concerns**
#
# * Discussion on the potential challenges and concerns related to AI adoption in India, including:
# 	+ Job displacement and unemployment
# 	+ Bias and fairness in AI systems
# 	+ Cybersecurity and data protection
# 	+ Regulatory frameworks and governance
#
# **VII. Future Prospects and Opportunities**
#
# * Analysis of the future prospects and opportunities for AI in India, including:
# 	+ Emerging industries and applications of AI, such as autonomous vehicles and robotics
# 	+ Growing demand for AI talent and skills
# 	+ Potential for AI to drive economic growth and development in India
#
# **VIII. Conclusion**
#
# * Summary of the key points discussed in the blog post
# * Final thoughts on the rise of AI in India and its potential to transform the country's economy and society.
#
# **IX. References**
#
# * List of sources cited in the blog post, including academic papers, industry reports, and news articles.
#
# This outline provides a comprehensive structure for a detailed blog post on the rise of AI in India, covering various aspects of AI adoption, government initiatives, startup ecosystem, talent acquisition, challenges, and future prospects.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: Opportunities, Challenges, and Future Prospects**
#
# **I. Introduction**
#
# Artificial Intelligence (AI) has revolutionized various industries and aspects of modern life, transforming the way we live, work, and interact with each other. As the world becomes increasingly dependent on AI, India is poised to become a global leader in AI adoption and innovation. With its burgeoning population, growing economy, and favorable government policies, India is uniquely positioned to harness the power of AI and drive digital transformation.
#
# India's significance as a hub for AI adoption and innovation lies in its vast talent pool, entrepreneurial spirit, and government initiatives that promote innovation and digital growth. The Indian government has recognized the potential of AI to drive economic growth, improve governance, and enhance the quality of life for its citizens. This has led to the establishment of various initiatives, programs, and policies that aim to promote AI adoption and innovation in the country.
#
# **Thesis statement:** India is poised to become a global leader in AI adoption, driven by government initiatives, technological advancements, and a growing demand for digital transformation.
#
# **II. Government Initiatives and Policies**
#
# The Indian government has taken several initiatives to promote AI adoption and innovation in the country. Some of the key initiatives include:
#
# 1. **Digital India Programme**: Launched in 2015, the Digital India Programme aims to transform India into a digitally empowered society and knowledge economy. The program focuses on five key areas: digital infrastructure, digital literacy, digital services, digital resources, and digital empowerment.
# 2. **Smart City Mission**: Launched in 2015, the Smart City Mission aims to create 100 smart cities in India, with a focus on sustainable development, efficient governance, and citizen-centric services.
# 3. **National Policy on Artificial Intelligence (2018)**: The National Policy on AI aims to promote AI adoption and innovation in India, focusing on areas such as AI research, development, and deployment. The policy also emphasizes the need for responsible AI development and deployment.
#
# These government initiatives have played a crucial role in promoting AI adoption and innovation in India. They have created a favorable ecosystem for startups, entrepreneurs, and organizations to develop and deploy AI solutions.
#
# **III. AI Adoption in Key Sectors**
#
# AI adoption is gaining traction in various sectors in India, including:
#
# 1. **Healthcare**: AI is being used in medical diagnosis, patient care, and telemedicine. For example, AI-powered chatbots are being used to provide mental health support to patients.
# 2. **Finance**: AI is being used in banking, insurance, and financial inclusion. For example, AI-powered chatbots are being used to provide customer support and assist with loan applications.
# 3. **Education**: AI is being used in personalized learning, online education, and skill development. For example, AI-powered adaptive learning platforms are being used to provide personalized learning experiences to students.
# 4. **Manufacturing**: AI is being used in quality control, predictive maintenance, and supply chain management. For example, AI-powered predictive maintenance systems are being used to predict equipment failures and reduce downtime.
#
# AI adoption in these sectors is expected to bring about significant benefits, including improved efficiency, productivity, and customer satisfaction.
#
# **IV. AI Startups and Entrepreneurship**
#
# India has a thriving AI startup ecosystem, with a growing number of startups working on AI-related projects. Some of the key trends and challenges in the AI startup ecosystem in India include:
#
# 1. **Growing number of AI startups**: The number of AI startups in India has grown significantly over the past few years, with many startups working on AI-related projects such as computer vision, natural language processing, and machine learning.
# 2. **Funding and success stories**: AI startups in India have raised significant funding from investors, with many startups achieving success and expanding their operations globally.
# 3. **Role of accelerators, incubators, and venture capital firms**: Accelerators, incubators, and venture capital firms have played a crucial role in promoting AI startups in India, providing them with funding, mentorship, and access to networks.
#
# However, AI startups in India also face several challenges, including funding, talent acquisition, and regulation.
#
# **V. Talent Acquisition and Development**
#
# The talent shortage in AI and data science is a significant challenge in India. To address this challenge, the government and private sector organizations have launched various initiatives to develop AI talent in India, including:
#
# 1. **AI education and training programs**: Many universities and institutions in India have launched AI education and training programs, providing students with the skills and knowledge required to work in AI-related fields.
# 2. **Government initiatives**: The government has launched various initiatives to develop AI talent in India, including the establishment of AI research centers and the provision of funding for AI-related projects.
# 3. **Private sector initiatives**: Private sector organizations have also launched various initiatives to develop AI talent in India, including the establishment of AI research centers and the provision of funding for AI-related projects.
#
# **VI. Challenges and Concerns**
#
# Despite the significant opportunities and benefits of AI adoption in India, there are several challenges and concerns related to AI adoption, including:
#
# 1. **Job displacement and unemployment**: AI adoption is expected to lead to job displacement and unemployment, particularly in sectors where AI is being used to automate tasks.
# 2. **Bias and fairness in AI systems**: AI systems can perpetuate bias and unfairness, particularly if they are trained on biased data or designed with a particular worldview.
# 3. **Cybersecurity and data protection**: AI systems are vulnerable to cybersecurity threats and data breaches, which can compromise sensitive information and put individuals at risk.
# 4. **Regulatory frameworks and governance**: The regulatory frameworks and governance structures in India are still evolving, and there is a need for clearer guidelines and regulations related to AI adoption.
#
# **VII. Future Prospects and Opportunities**
#
# The future prospects and opportunities for AI in India are significant, with several emerging industries and applications of AI, including:
#
# 1. **Autonomous vehicles and robotics**: AI is being used to develop autonomous vehicles and robotics, which are expected to transform the logistics and transportation sectors.
# 2. **Growing demand for AI talent and skills**: The demand for AI talent and skills is growing rapidly, with many organizations seeking to hire AI professionals and develop their AI capabilities.
# 3. **Potential for AI to drive economic growth and development**: AI has the potential to drive economic growth and development in India, particularly in sectors such as healthcare, finance, and education.
#
# **VIII. Conclusion**
#
# The rise of AI in India is a significant trend that is expected to transform the country's economy and society. With its favorable government policies, growing demand for digital transformation, and thriving startup ecosystem, India is poised to become a global leader in AI adoption and innovation. However, there are several challenges and concerns related to AI adoption, including job displacement, bias and fairness, cybersecurity, and regulatory frameworks. To address these challenges, there is a need for greater awareness, education, and training, as well as the development of clearer guidelines and regulations related to AI adoption.
#
# **IX. References**
#
# 1. "National Policy on Artificial Intelligence" (2018)
# 2. "Digital India Programme" (2015)
# 3. "Smart City Mission" (2015)
# 4. "AI in India: Opportunities, Challenges, and Future Prospects" (report by PwC)
# 5. "The Future of AI in India" (report by McKinsey)
# 6. "AI and Robotics in India" (report by Deloitte)
# 7. "India's AI Startup Ecosystem" (report by NASSCOM)
# 8. "AI Education and Training in India" (report by World Economic Forum)
